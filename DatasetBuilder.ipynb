# %%
import requests
from urllib.parse import urlencode
import base64
import webbrowser

# %%
username = 'neelptl2015'
client_id = ""
client_secret = ""

auth_headers = {
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": "https://localhost:3939/callback",
    "scope": "user-read-private"
}

webbrowser.open("https://accounts.spotify.com/authorize?" + urlencode(auth_headers))
# Out:
# True

# %%
code = 'AQCjA9DXRo5ViCMUBfqhbIQgAioQSNNN-QE8uDsanEUKM2OuHON0jrZ7tE9YPw4nh4_Z91oahVjC2IXsSG1GJRrWYdRJvDjxMinRVcd53DxvoxK0cWyu-EuEmAyf3ZX23Kz4i7xT3OYBjnu1hLAL7atmPAz1Ap3S1d5lYvZchu9R9lBCnGiwxEluuXJGCFdqcfYiGovX'
encoded_credentials = base64.b64encode(client_id.encode() + b':' + client_secret.encode()).decode("utf-8")

token_headers = {
    "Authorization": "Basic " + encoded_credentials,
    "Content-Type": "application/x-www-form-urlencoded"
}

token_data = {
    "grant_type": "authorization_code",
    "code": code,
    "redirect_uri": "https://localhost:3939/callback"
}

r = requests.post("https://accounts.spotify.com/api/token", data=token_data, headers=token_headers)

# %%
token = r.json()['access_token']
r.json()
# Out:
# {'access_token': 'BQD9orpW896VXsMGvMiI_usWHmPlymwudhxKOfjhMVRJKdZHPFRYt06BtlD1FuSZA_WSIxvwwlCF9mcrV4dmw46rWebLCnu7lfPy3AyEtXI_6kQUssp-l07KMSZIPosugDq7V59UdDbfeYSzS-6orzazZzs0VL06bOJorB-kcvCX01n-4HzPSm4XJiMrI_aL',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'refresh_token': 'AQDLRRkqBrCCzxdnWrm8Tl0irVGA33PIOPT0IGgjuw8-xLqhGc2zzg8mhhIv7IG0GpQrs8NyLko8hFfXMpl3Aw8iRvPwCdX3mbXOsQ7BuYdwajKAWzQPWrgRGyZCqmbnabE',
#  'scope': 'user-read-private'}

# %%
def current_user_playlists(token):
    API_URL = f"https://api.spotify.com/v1/users/{username}/playlists"

    response = requests.get(API_URL,
                            headers={"Authorization": f"Bearer {token}"},
                            )
    playlists = response.json()
    return playlists

def playlist_tracks(playlist_ID, token):
    API_URL = f"https://api.spotify.com/v1/playlists/{playlist_ID}/tracks"
    response = requests.get(API_URL,
                            headers={"Authorization": f"Bearer {token}"}

                            )
    playlist_data = response.json()
    return playlist_data

# %%
##getting a users playlist and iterate through the playlist
i = 0
user_playlist = current_user_playlists(token)
total = user_playlist['total']
while i < total:
    print(user_playlist['items'][i]['name'] + ": " + user_playlist['items'][i]['id'])
    i = i + 1;
# Out:
# Round 2: 2aqvuX32Bff87CJ67cKijV
# Clinically Narcissistic : 3y6IV3gNK5LS9IdQCY6v7a
# My playlist #29: 3W86sBtazgrym7Vbsi7Vm4
# Hot tub Js : 1tnJPdw4bNgcWYqkuz4Nim
# Y1: 0UjvtVUYemlGVAeaSyH1lk
# S.T.R: 375mYNwT6rKvG7BtM7NdzF
# Throwbacks: 2li29Ri64Fza5BKK6t0LNM
# MID West Emo: 2JNfAcFx6PGg2qhyeeLjl8
# 🪨 : 5p348bjobGLhnCG92gbWU9
# The big one : 6OPTkxfLEvNbi5HyoS42if

# %%
# getting information about a playlist
track_limit = 200
playlist = playlist_tracks('2JNfAcFx6PGg2qhyeeLjl8', token) # using clinically narcissitic for trials

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2JNfAcFx6PGg2qhyeeLjl8/tracks?offset=0&limit=100',
#  'items': [{'added_at': '2022-01-21T22:29:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/neelptl2015'},
#     'href': 'https://api.spotify.com/v1/users/neelptl2015',
#     'id': 'neelptl2015',
#     'type': 'user',
#     'uri': 'spotify:user:neelptl2015'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mPyBjLQNaO5XwUyTXf5wL'},
#        'href': 'https://api.spotify.com/v1/artists/3mPyBjLQNaO5XwUyTXf5wL',
#        'id': '3mPyBjLQNaO5XwUyTXf5wL',
#        'name': 'Disco Inc.',
#        'type': 'artist',
#        'uri': 'spotify:artist:3mPyBjLQNaO5XwUyTXf5wL'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNfnkHqbNqPMm0LY98Tfx'},
# ...

# %%
playlist['items'][0]['track']['name']
# Out:
# "Ghost of Mariano's"

# %%
#total = playlist['items']['tracks']['total']
#limit =  playlist['items']['tracks']['limit']

#playlist['tracks']['items'][0]

# %%
#current issues: total is greater than limmit, limit is constricted to 100 songs per request
total = 100
limit = 100
i = 0
tracklist = []
if limit < total:
    iter = limit
else:
    iter = total

while i < iter:
    print(playlist['tracks']['items'][i]['track']['name'])
    tracklist.append(playlist['tracks']['items'][i]['track']['id'])
    i = i + 1;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 12
#       9     iter = total
#      11 while i < iter:
# ---> 12     print(playlist['tracks']['items'][i]['track']['name'])
#      13     tracklist.append(playlist['tracks']['items'][i]['track']['id'])
#      14     i = i + 1;
#
# TypeError: list indices must be integers or slices, not str

# %%
#getting a more specific category list for the genres
for artist in playlist['tracks']['items'][0]['track']['artists']:
    artist_id = artist['id']
    more_artist_data = sp.artist(artist_id)
    for genre in more_artist_data['genres']: 
        genre_list.append(genre)
    
print(genre_list)
