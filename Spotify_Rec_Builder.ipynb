# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset.csv/Testdata_1.csv')

# %%
df.tail(30)
# Out:
#         Unnamed: 0                track_id  \
# 113970      113970  3IxffkznUu2I4mx9OWibW5
# 113971      113971  4aLBgBxa1ajNoWD3OSDay6
# 113972      113972  6xZuzUxNn5AGIPQ2FvXXLP
# 113973      113973  1d2LyEJ1zZ0gWtlxyZQpDE
# 113974      113974  0VVvjjtKyOeT2AEMTSQ33t
# 113975      113975  2yAo8cJDVoMjBMS5MgrO8P
# 113976      113976  11Jywidl4OVzmjziGR0QiO
# 113977      113977  3FuOBnk7Xsglp7AIsHQVaA
# 113978      113978  7IPetVJ4VQgCT5Sh5VA4h1
# 113979      113979  5wMkhfu3oYYmFimOGzeFt2
# 113980      113980  64BdW5aHuB3C0QP3qjBJVi
# 113981      113981  1pBc7W7UQacUeQ6kBVlN9f
# 113982      113982  39So2wAM6l3XKWDf5XjiIz
# 113983      113983  6X6wIzuxsh7GVNMPz1xTNa
# 113984      113984  0PjyOURxQ6wiHaBYXf53G2
# 113985      113985  5y8ARSg47Yx52xvQQAlS35
# 113986      113986  2ZYEpnio0Z6EfJWy2JAf53
# 113987      113987  4jDhzTYkEG5GloIWwVeVkc
# 113988      113988  6PM55W7WiUmHVPdUebJP55
# 113989      113989  0XEgJiDryoDd2gIJhVXghd
# 113990      113990  2A4dSiJmbviL56CBupkh6C
# 113991      113991  0CE0Y6GM75cbrqao8EOAlW
# 113992      113992  3FjOBB4EyIXHYUtSgrIdY9
# 113993      113993  4OkMK49i3NApR1KsAIsTf6
# 113994      113994  4WbOUe6T0sozC7z5ZJgiAA
# 113995      113995  2C3TZjDRiAzdyViavDJ217
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5
#
#                                        artists  \
# 113970    Cuencos Tibetanos Sonidos Relajantes
# 113971                             Ondas Delta
# 113972                                 Mc_team
# 113973                        Vertical Worship
# 113974                            Chris Tomlin
# 113975  Hillsong Worship;Hillsong Young & Free
# 113976                            Urban Rescue
# 113977                           Reiki Armonía
# 113978                          Lucas Cervetti
# 113979                     Fondo de la lectura
# 113980                               I AM THEY
# 113981                           Planetshakers
# 113982                           Planetshakers
# 113983                        Hillsong Worship
# 113984                      Tenth Avenue North
# 113985                              Mosaic MSC
# 113986                           Dulces Sueños
# 113987                           Planetshakers
# 113988                           Planetshakers
# 113989       Bryan & Katie Torwalt;Brock Human
# 113990                          Lucas Cervetti
# 113991                            Chris Tomlin
# 113992                           Jesus Culture
# 113993                            Chris Tomlin
# 113994                          Lucas Cervetti
# 113995                           Rainy Lullaby
# 113996                           Rainy Lullaby
# 113997                           Cesária Evora
# 113998                        Michael W. Smith
# 113999                           Cesária Evora
#
#                                                album_name  \
# 113970                       Tibetanos Sonidos Relajantes
# 113971  Abre Tu Mente: Música con Sonidos Binaurales y...
# 113972             Frecuencias Curativas Solfeggio 528 Hz
# 113973                                The Rock Won't Move
# 113974                        And If Our God Is For Us...
# 113975                           OPEN HEAVEN / River Wild
# 113976                                         Wild Heart
# 113977  Música Relajante para Reiki - Canciones de Fon...
# 113978                                       Trempülkalwe
# 113979                Concentración: Sonidos de la Lluvia
# 113980                                          I AM THEY
# 113981                                     Greater (Live)
# 113982                                       All For Love
# 113983                                      No Other Name
# 113984                           The Light Meets The Dark
# 113985                              HUMAN (Deluxe) [Live]
# 113986  #20 Sueños Vividos - Música Intrumental Suave ...
# 113987                                     Revival (Live)
# 113988                                     Greater (Live)
# 113989                 I've Got Good News (Live) [Deluxe]
# 113990          Frecuencias Álmicas en 432hz (Solo Piano)
# 113991                              The Ultimate Playlist
# 113992                                   Revelation Songs
# 113993                  See The Morning (Special Edition)
# 113994                       Frecuencias Álmicas en 432hz
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                                          track_name  popularity  duration_ms  \
# 113970                                  De Conexion          21        96302
# 113971                       Ondas Cerebrales Delta          21       359003
# 113972                 528Hz La frecuencia del amor          21       170387
# 113973                                I Will Follow          44       260839
# 113974                                     Faithful          34       285120
# 113975                               This Is Living          38       214647
# 113976                                 Alive In You          42       253546
# 113977                                   Paz Mental          21       290999
# 113978                                   Maremágnum          21       260506
# 113979  Concentración: Sonidos de la Lluvia, Pt. 01          22       143403
# 113980                                         Amen          41       238146
# 113981                     Heaven Is My Home - Live          39       289179
# 113982                             Come Holy Spirit          36       352453
# 113983                                       Depths          37       377697
# 113984                               Healing Begins          44       237280
# 113985                  Fountain (I Am Good) - Live          22       318874
# 113986                               Sueños Vividos          21       335999
# 113987                           All My Life - Live          40       246306
# 113988                   Stay (You Are Good) - Live          38       462397
# 113989                Hallelujah On My Knees - Live          22       380344
# 113990            Frecuencia Álmica XI - Solo Piano          22       369049
# 113991                  At The Cross (Love Ran Red)          32       250629
# 113992                        Your Love Never Fails          38       312566
# 113993                  How Can I Keep From Singing          39       256026
# 113994                     Frecuencia Álmica, Pt. 4          22       305454
# 113995                          Sleep My Little Boy          21       384999
# 113996                             Water Into Light          22       385000
# 113997                               Miss Perfumado          22       271466
# 113998                                      Friends          41       283893
# 113999                                    Barbincor          22       241826
#
#         explicit  danceability  energy  ...  loudness  mode  speechiness  \
# 113970     False        0.1210  0.2420  ...   -17.980     1       0.0375
# 113971     False        0.3120  0.0330  ...   -25.894     1       0.0307
# 113972     False        0.1700  0.0520  ...   -28.693     1       0.0374
# 113973     False        0.3190  0.5770  ...    -7.679     1       0.0330
# 113974     False        0.6180  0.4190  ...    -6.156     1       0.0279
# 113975     False        0.6110  0.8570  ...    -6.248     0       0.0384
# 113976     False        0.5220  0.6970  ...    -7.210     1       0.0344
# 113977     False        0.0672  0.0903  ...   -23.496     1       0.0401
# 113978     False        0.4050  0.2830  ...    -9.471     1       0.0300
# 113979     False        0.4170  0.9670  ...   -27.146     0       0.0503
# 113980     False        0.5160  0.6340  ...    -4.850     1       0.0339
# 113981     False        0.4980  0.9570  ...    -5.807     0       0.1620
# 113982     False        0.4370  0.6380  ...    -6.483     0       0.0308
# 113983     False        0.3630  0.4620  ...    -8.232     1       0.0284
# 113984     False        0.5410  0.5830  ...    -7.047     1       0.0285
# 113985     False        0.4380  0.5770  ...    -8.285     1       0.0357
# 113986     False        0.1980  0.2570  ...   -17.361     1       0.0415
# 113987     False        0.4700  0.9380  ...    -4.722     0       0.1050
# 113988     False        0.2960  0.7620  ...    -5.696     1       0.0548
# 113989     False        0.4950  0.2810  ...   -12.070     1       0.0316
# 113990     False        0.5790  0.2450  ...   -16.357     1       0.0384
# 113991     False        0.3870  0.5310  ...    -4.788     1       0.0290
# 113992     False        0.4750  0.8600  ...    -4.722     1       0.0421
# 113993     False        0.5050  0.6870  ...    -4.375     1       0.0287
# 113994     False        0.3310  0.1710  ...   -15.668     1       0.0350
# 113995     False        0.1720  0.2350  ...   -16.393     1       0.0422
# 113996     False        0.1740  0.1170  ...   -18.318     0       0.0401
# 113997     False        0.6290  0.3290  ...   -10.895     0       0.0420
# 113998     False        0.5870  0.5060  ...   -10.889     1       0.0297
# 113999     False        0.5260  0.4870  ...   -10.204     0       0.0725
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 113970      0.000878          0.813000    0.1200   0.0362   85.784
# 113971      0.853000          0.851000    0.1140   0.0639   79.655
# 113972      0.875000          0.904000    0.1290   0.0475  114.573
# 113973      0.049900          0.000000    0.7290   0.1890   97.678
# 113974      0.309000          0.000000    0.1070   0.3730  131.973
# 113975      0.001820          0.000000    0.3260   0.4640  128.001
# 113976      0.055700          0.000000    0.1340   0.2880   75.972
# 113977      0.970000          0.977000    0.0930   0.0361   76.042
# 113978      0.894000          0.806000    0.1190   0.0813   99.947
# 113979      0.924000          0.958000    0.6960   0.0147   65.002
# 113980      0.030000          0.000002    0.0813   0.0921   76.994
# 113981      0.005270          0.000000    0.4770   0.2050  128.028
# 113982      0.211000          0.000428    0.1380   0.1590  148.000
# 113983      0.008870          0.000009    0.7060   0.0687   80.003
# 113984      0.014200          0.000000    0.1020   0.2760   96.008
# 113985      0.020600          0.000013    0.2530   0.1140  139.983
# 113986      0.968000          0.949000    0.1100   0.0381   89.494
# 113987      0.000529          0.000000    0.2510   0.4530  128.002
# 113988      0.072400          0.000003    0.3740   0.1460  139.051
# 113989      0.392000          0.000000    0.6620   0.2060  127.731
# 113990      0.970000          0.924000    0.1010   0.3020  112.011
# 113991      0.003050          0.000000    0.2010   0.1530  146.003
# 113992      0.006500          0.000002    0.2460   0.4270  113.949
# 113993      0.084100          0.000000    0.1880   0.3820  104.083
# 113994      0.920000          0.022900    0.0679   0.3270  132.147
# 113995      0.640000          0.928000    0.0863   0.0339  125.995
# 113996      0.994000          0.976000    0.1050   0.0350   85.239
# 113997      0.867000          0.000000    0.0839   0.7430  132.378
# 113998      0.381000          0.000000    0.2700   0.4130  135.960
# 113999      0.681000          0.000000    0.0893   0.7080   79.198
#
#         time_signature  track_genre
# 113970               4  world-music
# 113971               4  world-music
# 113972               4  world-music
# 113973               4  world-music
# 113974               4  world-music
# 113975               4  world-music
# 113976               4  world-music
# 113977               4  world-music
# 113978               4  world-music
# 113979               4  world-music
# 113980               4  world-music
# 113981               4  world-music
# 113982               4  world-music
# 113983               4  world-music
# 113984               4  world-music
# 113985               4  world-music
# 113986               4  world-music
# 113987               4  world-music
# 113988               4  world-music
# 113989               4  world-music
# 113990               3  world-music
# 113991               4  world-music
# 113992               4  world-music
# 113993               3  world-music
# 113994               3  world-music
# 113995               5  world-music
# 113996               4  world-music
# 113997               4  world-music
# 113998               4  world-music
# 113999               4  world-music
#
# [30 rows x 21 columns]

# %%
unique_values = list(set(df['track_genre']))

# Print the unique values
print("Unique Values:", unique_values)
# Out:
# Unique Values: ['heavy-metal', 'romance', 'guitar', 'latino', 'children', 'funk', 'anime', 'idm', 'acoustic', 'bluegrass', 'minimal-techno', 'dance', 'piano', 'british', 'disney', 'hard-rock', 'k-pop', 'disco', 'study', 'gospel', 'groove', 'latin', 'j-rock', 'pop', 'happy', 'swedish', 'emo', 'industrial', 'comedy', 'metalcore', 'power-pop', 'rockabilly', 'synth-pop', 'hip-hop', 'sertanejo', 'j-pop', 'electro', 'hardstyle', 'alternative', 'punk-rock', 'indian', 'psych-rock', 'r-n-b', 'iranian', 'club', 'turkish', 'sad', 'country', 'garage', 'breakbeat', 'french', 'singer-songwriter', 'punk', 'tango', 'death-metal', 'honky-tonk', 'dub', 'mandopop', 'forro', 'indie-pop', 'songwriter', 'reggaeton', 'metal', 'chill', 'j-dance', 'soul', 'malay', 'spanish', 'jazz', 'chicago-house', 'ska', 'kids', 'party', 'sleep', 'electronic', 'salsa', 'folk', 'detroit-techno', 'brazil', 'edm', 'grindcore', 'progressive-house', 'new-age', 'afrobeat', 'techno', 'drum-and-bass', 'blues', 'deep-house', 'hardcore', 'mpb', 'german', 'world-music', 'alt-rock', 'ambient', 'reggae', 'black-metal', 'grunge', 'dubstep', 'rock-n-roll', 'cantopop', 'house', 'classical', 'opera', 'samba', 'pop-film', 'j-idol', 'trip-hop', 'pagode', 'indie', 'rock', 'dancehall', 'trance', 'goth', 'show-tunes']

# %%
count = df['track_genre'].value_counts() 
print(count)
# Out:
# track_genre
# acoustic             1000
# punk-rock            1000
# progressive-house    1000
# power-pop            1000
# pop                  1000
#                      ...
# folk                 1000
# emo                  1000
# electronic           1000
# electro              1000
# world-music          1000
# Name: count, Length: 114, dtype: int64

# %%
grouped = df.groupby('track_genre')

# %%
grouped.head()
# Out:
#         Unnamed: 0                track_id  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV
# 1                1  4qPNDBW1i3p13qLCt0Ki3A
# 2                2  1iJBSr7s7jYXzM8EGcbK5b
# 3                3  6lfxq3CG4xtTiEg7opyCyx
# 4                4  5vjLSffimiIP26QG5WcN2K
# ...            ...                     ...
# 113000      113000  5XCtjnFMKtCT7ycDwV3Kdh
# 113001      113001  0fxpHpK3aw2nFWII6yveDD
# 113002      113002  0rH0mprtecH3grD9HFM5AD
# 113003      113003  1O6OPFAXdTdjHtT7Z2Hlt8
# 113004      113004  0H4BGX7L8UfoD0g4wgXd0D
#
#                                    artists  \
# 0                              Gen Hoshino
# 1                             Ben Woodward
# 2                   Ingrid Michaelson;ZAYN
# 3                             Kina Grannis
# 4                         Chord Overstreet
# ...                                    ...
# 113000  Hillsong Worship;Brooke Ligertwood
# 113001                         Matt Redman
# 113002                         Cory Asbury
# 113003           Bethel Music;Jenn Johnson
# 113004                             Leeland
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113000                              What A Beautiful Name
# 113001                              10,000 Reasons (Live)
# 113002                                      Reckless Love
# 113003                                              Peace
# 113004                                          Way Maker
#
#                                     track_name  popularity  duration_ms  \
# 0                                       Comedy          73       230666
# 1                             Ghost - Acoustic          55       149610
# 2                               To Begin Again          57       210826
# 3                   Can't Help Falling In Love          71       201933
# 4                                      Hold On          82       198853
# ...                                        ...         ...          ...
# 113000                   What A Beautiful Name          66       240200
# 113001  10,000 Reasons (Bless The Lord) - Live          66       342493
# 113002                           Reckless Love          70       333386
# 113003                         Goodness of God          61       456480
# 113004              Way Maker - Single Version          64       206440
#
#         explicit  danceability  energy  ...  loudness  mode  speechiness  \
# 0          False         0.676  0.4610  ...    -6.746     0       0.1430
# 1          False         0.420  0.1660  ...   -17.235     1       0.0763
# 2          False         0.438  0.3590  ...    -9.734     1       0.0557
# 3          False         0.266  0.0596  ...   -18.515     1       0.0363
# 4          False         0.618  0.4430  ...    -9.681     1       0.0526
# ...          ...           ...     ...  ...       ...   ...          ...
# 113000     False         0.417  0.4990  ...    -6.364     1       0.0296
# 113001     False         0.431  0.4850  ...    -8.085     1       0.0274
# 113002     False         0.572  0.6850  ...    -7.290     1       0.0356
# 113003     False         0.370  0.1190  ...   -11.513     1       0.0392
# 113004     False         0.468  0.6550  ...    -6.384     1       0.0296
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 0             0.0322          0.000001    0.3580    0.715   87.917
# 1             0.9240          0.000006    0.1010    0.267   77.489
# 2             0.2100          0.000000    0.1170    0.120   76.332
# 3             0.9050          0.000071    0.1320    0.143  181.740
# 4             0.4690          0.000000    0.0829    0.167  119.949
# ...              ...               ...       ...      ...      ...
# 113000        0.2120          0.000000    0.1120    0.144  135.923
# 113001        0.4520          0.000000    0.5440    0.367  145.220
# 113002        0.0291          0.000000    0.0963    0.232  110.698
# 113003        0.9530          0.000002    0.0990    0.183  110.424
# 113004        0.0149          0.000000    0.1040    0.222  144.045
#
#         time_signature  track_genre
# 0                    4     acoustic
# 1                    4     acoustic
# 2                    4     acoustic
# 3                    3     acoustic
# 4                    4     acoustic
# ...                ...          ...
# 113000               4  world-music
# 113001               4  world-music
# 113002               4  world-music
# 113003               4  world-music
# 113004               4  world-music
#
# [570 rows x 21 columns]

# %%
# exploring how data varies among different genres
pop_avg = grouped['popularity'].mean()

# %%
pop_avg.head()
# Out:
# track_genre
# acoustic       42.483
# afrobeat       24.399
# alt-rock       33.943
# alternative    24.337
# ambient        44.191
# Name: popularity, dtype: float64

# %%
pop_avg = pop_avg.sort_values(ascending=False)
print(pop_avg)
# Out:
# track_genre
# pop-film          59.283
# k-pop             56.896
# chill             53.651
# sad               52.379
# grunge            49.594
#                    ...
# chicago-house     12.339
# detroit-techno    11.174
# latin              8.297
# romance            3.245
# iranian            2.210
# Name: popularity, Length: 114, dtype: float64

# %%
plt.boxplot(pop_avg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x229a7584ee0>,
#   <matplotlib.lines.Line2D at 0x229a7585180>],
#  'caps': [<matplotlib.lines.Line2D at 0x229a7585420>,
#   <matplotlib.lines.Line2D at 0x229a75856c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x229a7584c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x229a7585960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229a7585c00>],
#  'means': []}

# %%
dance_avg = grouped['danceability'].mean()
dance_avg = dance_avg.sort_values(ascending=False)
print(dance_avg)
plt.boxplot(dance_avg)
# Out:
# track_genre
# kids             0.778906
# chicago-house    0.766176
# reggaeton        0.758521
# latino           0.757057
# reggae           0.745331
#                    ...
# opera            0.313563
# iranian          0.300686
# black-metal      0.296411
# grindcore        0.271854
# sleep            0.167923
# Name: danceability, Length: 114, dtype: float64
# {'whiskers': [<matplotlib.lines.Line2D at 0x229a75d0580>,
#   <matplotlib.lines.Line2D at 0x229a75d0700>],
#  'caps': [<matplotlib.lines.Line2D at 0x229a75d09a0>,
#   <matplotlib.lines.Line2D at 0x229a75d0c40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x229a75d02e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x229a75d0ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229a75d1180>],
#  'means': []}

# %%
energy_avg = grouped['energy'].mean()
energy_avg = energy_avg.sort_values(ascending=False)
print(energy_avg)
plt.boxplot(energy_avg)
# Out:
# track_genre
# death-metal    0.931470
# grindcore      0.924201
# metalcore      0.914485
# happy          0.910971
# hardstyle      0.901246
#                  ...
# disney         0.302519
# romance        0.294304
# ambient        0.237162
# new-age        0.214501
# classical      0.189827
# Name: energy, Length: 114, dtype: float64
# {'whiskers': [<matplotlib.lines.Line2D at 0x229a761bc70>,
#   <matplotlib.lines.Line2D at 0x229a761bf10>],
#  'caps': [<matplotlib.lines.Line2D at 0x229a76541f0>,
#   <matplotlib.lines.Line2D at 0x229a7654490>],
#  'boxes': [<matplotlib.lines.Line2D at 0x229a761b9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x229a7654730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x229a76549d0>],
#  'means': []}

# %%
## bucketing release year into 5 different years
#scratching this, as dataset has no dates: plan to come back and find a more usful dataset

# %%
## using the spotify API- retriving a playlist

def getplaylistdata(playlist_ID, Token):
    Token = "BQCcY93hX3EfheSPt8rCpo8aHQEsiasZzpt41ntfUIIR9ZIPJUYSlLa7JWqUXeMRH6-9Ik8yHxTh65s0WJn4XOY7biIHFRTcMyQ_mRHQtyplz-MHwcNLCce_i3ngl0mLAwAeNPjMF7ND_2OMYI7-U62nth_wm7P3f7GRVYsGfEgxUL6k"
    API_URL = f"https://api.spotify.com/v1/playlists/{playlist_ID}/tracks"

    response = requests.get(API_URL,
                            headers={"Authorization": f"Bearer {Token}"}

                            )
    playlist_data = response.json()
    return playlist_data

def getplaylists(Token):

    API_URL = "	https://api.spotify.com/v1/users/neelptl2015/playlists"

    response = requests.get(API_URL,
                            headers={"Authorization": f"Bearer {Token}"},
                            )
    playlists = response.json()
    return playlists

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
##must deal and remove this later- unsercue halding of private info
client_id = "6c23880f6c3149f5813b6983e814aea8"
private_id = "b3e08ed764984ebc88efceb2b9efbf97"
redirect = "http://localhost:3939"


##code for authentification and scope determindation
scope = "user-library-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id= client_id, client_secret= private_id, redirect_uri= redirect, scope=scope))

# %%
##getting a users playlist and iterate through the playlist
i = 0
user_playlist = sp.current_user_playlists(limit= 50, offset=0)
total = user_playlist['total']
while i < total:
    print(user_playlist['items'][i]['name'] + ": " + user_playlist['items'][i]['id'])
    i = i + 1;
# Out:
# Round 2: 2aqvuX32Bff87CJ67cKijV
# Clinically Narcissistic : 3y6IV3gNK5LS9IdQCY6v7a
# My playlist #29: 3W86sBtazgrym7Vbsi7Vm4
# Hot tub Js : 1tnJPdw4bNgcWYqkuz4Nim
# Y1: 0UjvtVUYemlGVAeaSyH1lk
# S.T.R: 375mYNwT6rKvG7BtM7NdzF
# Throwbacks: 2li29Ri64Fza5BKK6t0LNM
# MID West Emo: 2JNfAcFx6PGg2qhyeeLjl8
# 🪨 : 5p348bjobGLhnCG92gbWU9
# The big one : 6OPTkxfLEvNbi5HyoS42if

# %%
# getting information about a playlist
track_limit = 200
playlist = sp.playlist('3y6IV3gNK5LS9IdQCY6v7a') # using clinically narcissitic for trials

# %%
total = playlist['tracks']['total']
limit =  playlist['tracks']['limit']

#playlist['tracks']['items'][0]

# %%
playlist['tracks']['items'][0]['track']
# Out:
# {'preview_url': 'https://p.scdn.co/mp3-preview/f4f13751297cc17a1f284bae8a13b30572c08770?cid=6c23880f6c3149f5813b6983e814aea8',
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'explicit': False,
#  'type': 'track',
#  'episode': False,
#  'track': True,
#  'album': {'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'type': 'album',
#   'album_type': 'album',
#   'href': 'https://api.spotify.com/v1/albums/1bwbZJ6khPJyVpOaqgKsoZ',
#   'id': '1bwbZJ6khPJyVpOaqgKsoZ',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b2736ed9aef791159496b286179f',
#     'width': 640,
#     'height': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e026ed9aef791159496b286179f',
#     'width': 300,
#     'height': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d000048516ed9aef791159496b286179f',
#     'width': 64,
#     'height': 64}],
#   'name': 'METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE SPIDER-VERSE (SOUNDTRACK FROM AND INSPIRED BY THE MOTION PICTURE)',
#   'release_date': '2023-06-02',
#   'release_date_precision': 'day',
#   'uri': 'spotify:album:1bwbZJ6khPJyVpOaqgKsoZ',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#     'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#     'id': '0iEtIxbK0KxaSlF7G42ZOp',
#     'name': 'Metro Boomin',
#     'type': 'artist',
#     'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1bwbZJ6khPJyVpOaqgKsoZ'},
#   'total_tracks': 13},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0iEtIxbK0KxaSlF7G42ZOp'},
#    'href': 'https://api.spotify.com/v1/artists/0iEtIxbK0KxaSlF7G42ZOp',
#    'id': '0iEtIxbK0KxaSlF7G42ZOp',
#    'name': 'Metro Boomin',
#    'type': 'artist',
#    'uri': 'spotify:artist:0iEtIxbK0KxaSlF7G42ZOp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#    'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#    'id': '1zNqQNIdeOUZHb8zbZRFMX',
#    'name': 'Swae Lee',
#    'type': 'artist',
#    'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7rkW85dBwwrJtlHRDkJDAC'},
#    'href': 'https://api.spotify.com/v1/artists/7rkW85dBwwrJtlHRDkJDAC',
#    'id': '7rkW85dBwwrJtlHRDkJDAC',
#    'name': 'NAV',
#    'type': 'artist',
#    'uri': 'spotify:artist:7rkW85dBwwrJtlHRDkJDAC'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/31W5EY0aAly4Qieq6OFu6I'},
#    'href': 'https://api.spotify.com/v1/artists/31W5EY0aAly4Qieq6OFu6I',
#    'id': '31W5EY0aAly4Qieq6OFu6I',
#    'name': 'A Boogie Wit da Hoodie',
#    'type': 'artist',
#    'uri': 'spotify:artist:31W5EY0aAly4Qieq6OFu6I'}],
#  'disc_number': 1,
#  'track_number': 6,
#  'duration_ms': 219453,
#  'external_ids': {'isrc': 'USUM72308543'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5rurggqwwudn9clMdcchxT'},
#  'href': 'https://api.spotify.com/v1/tracks/5rurggqwwudn9clMdcchxT',
#  'id': '5rurggqwwudn9clMdcchxT',
#  'name': 'Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)',
#  'popularity': 79,
#  'uri': 'spotify:track:5rurggqwwudn9clMdcchxT',
#  'is_local': False}

# %%
#current issues: total is greater than limmit, limit is constricted to 100 songs per request
i = 0
if limit < total:
    iter = limit
else:
    iter = total

while i < iter:
    print(playlist['tracks']['items'][i]['track']['name'])
    i = i + 1;
# Out:
# Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)
# THIS DOG DON'T BITE
# Antihero
# Braces
# Dizzy
# Pray For Me (with Kendrick Lamar)
# Hell Of A Life
# Soul Food II
# Spilt To Bill
# Foreword (feat. Rex Orange County)
# I Am A Cybernetic Organism, Living Tissue Over (Metal) Endoskeleton
# Touch Me I'm Sick
# X.Y.U. - Remastered 2012
# Naked
# Go - Remastered
# No Future For Me
# Everlong
# Yikes
# Colossus
# Parking Lot (feat. Casey Veggies & Mike G)
# Bullet With Butterfly Wings - Remastered 2012
# Rusty (feat. Domo Genesis & Earl Sweatshirt)
# REEL IT IN
# range brothers (with Kendrick Lamar)
# scapegoats
# Father Stretch My Hands Pt. 1
# No More Parties In LA
# Monster
# Ni**as In Paris
# Stronger
# F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar)
# Wesley's Theory
# DNA.
# HUMBLE.
# King's Dead (with Kendrick Lamar, Future & James Blake)
# Smells Like Teen Spirit
# Breed
# ORANGE SODA
# She
# Freaks And Geeks
# Neon Guts (feat. Pharrell Williams)
# first order of business
# Dead!
# Welcome to the Black Parade
# All The Stars (with SZA)
# trademark usa
# Can I Pet Ur Dog?
# CORSO
# NEW MAGIC WAND
# WHAT'S GOOD
# Nightmare
# Rhinestone Eyes
# Seven Across
# Pussy & Millions (feat. Travis Scott)
# New Gold (feat. Tame Impala and Bootie Brown)
# Spin Bout U
# Analog
# I Want to Kill You
# My Own Summer (Shove It)
# MX
# Be Quiet and Drive (Far Away)
# Around the Fur
# One More Hour
# Free Bird
# Lightsabers (feat. C Dot Castro)
# Death Dance Approximately
# Are You The One
# A Beginner's Guide to Destroying the Moon
# Mona Lisa (Spider-Man: Across the Spider-Verse)
# Them Bones (2022 Remaster)
# Junkhead (2022 Remaster)
# Dam That River (2022 Remaster)
# Sleep Now In the Fire
# Plug in Baby
# Brand New Draco
# Around Me (feat. Don Toliver)
# I'm Geekin
# paranoia
# OLD MONEY
# Girlfriend
# King of Pain
# One More Rep
# Get To The Choppa
# I'll Be Back
# Alpha Male
# Eyes Without A Face
# DOGTOOTH
# Duvet
# Nightcall
# Headlines
# Can't Stop
# New Noise
# Young Girl A
# 7 Words
# Suicide Doors
# From The Start
# The Story of O.J.
# Evergreen
# Sunday
# Bored

# %%
#Building Basic Dataframe of names and IDS
user_playlist_df = pd.DataFrame(columns=['track_id', 'name', 'popularity'])


i = 0
while i < iter:
    user_playlist_df.loc[i] = [
        playlist['tracks']['items'][i]['track']['id'],
        playlist['tracks']['items'][i]['track']['name'],
        playlist['tracks']['items'][i]['track']['popularity']
    ] 
    i = i + 1

# %%
user_playlist_df.head(5)
# Out:
#                  track_id                                               name  \
# 0  5rurggqwwudn9clMdcchxT  Calling (Spider-Man: Across the Spider-Verse) ...
# 1  7uzLB7B2pSpeuSNdD16K3j                                THIS DOG DON'T BITE
# 2  6lEWNMb01l9xjdbrYpoFzL                                           Antihero
# 3  3oYAMcCA1J8QGzz1q0CPHF                                             Braces
# 4  4Gj2FtTNmem7NGEOYJs812                                              Dizzy
#
#    popularity
# 0          79
# 1           0
# 2          19
# 3          42
# 4          46

# %%
user_playlist_df = user_playlist_df.append({
        'track_id': playlist['tracks']['items'][i]['track']['id'],
        'name': playlist['tracks']['items'][i]['track']['id'],
        'popularity': playlist['tracks']['items'][i]['track']['id']
    })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36104\250784861.py in ?()
# ----> 1 user_playlist_df = user_playlist_df.append({
#       2         'track_id': playlist['tracks']['items'][i]['track']['id'],
#       3         'name': playlist['tracks']['items'][i]['track']['id'],
#       4         'popularity': playlist['tracks']['items'][i]['track']['id']
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
